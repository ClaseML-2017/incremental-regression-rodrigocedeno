# %% [markdown]
# ### Linear regresion error curve
# Machine Learning <br />
# Rodrigo Cedeño

# %%
import pandas as pd
import numpy as np
import csv
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
df = pd.read_csv("regLin.csv")

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df[df.columns[0:-1]], df[[df.columns[-1]]], train_size = 0.75)

# %%
plt.scatter(X_train, Y_train)

# %%
Y_train = np.array(Y_train)
ln = LinearRegression()
ln.fit(X_train, Y_train)
Y_predict = ln.predict(X_test)

# %%
print ln.intercept_, ln.coef_
# Out:
# [ 2.61581032] [[ 0.606485]]

# %%
np.mean((ln.predict(X_test) - Y_test) ** 2)
# Out:
# y    15.707398
# dtype: float64

# %%
plt.scatter(X_test, Y_test)
plt.plot(X_test, Y_predict, color = 'red')

# %% [markdown]
# ### Ahora graficaremos el error

# %%
w0 = ln.intercept_
w1_value = ln.coef_[0][0]

#Cambiamos el error paso a paso
error = [np.mean((np.subtract((i*X_test + w0), Y_test))**2) for i in range(-100,101,1)]

plt.plot(W, error, color = "red")
plt.scatter(w0,np.mean(((w1*X_train + w0 )-Y_train)**2),color="blue")

# %% [markdown]
# ### Ahora utilizaremos el segundo archivo

# %%
df = pd.read_csv("regLin2.csv")

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df[df.columns[0:-1]], df[[df.columns[-1]]], train_size = 0.75)

# %%
plt.scatter(X_train, Y_train)

# %%
linreg = LinearRegression()
# método de transformación visto en clase donde se eleva cada valor de X al cuadrado:
X_train_2 = X_train**2
Y_train = np.array(Y_train)
linreg.fit(X_train_2, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
max_value_x_test = max(np.array(X_test))

# %%
linear_values = np.linspace(0, max_value_x_test)
plt.scatter(X_test, Y_test)
Y_predict = linreg.predict([[i**2] for i in linear_values])
plt.plot(linear_values, Y_predict, color='red')

# %% [markdown]
# ### Ahora utilizaremos el tercer archivo

# %%
df = pd.read_csv("regLin3.csv")

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df[df.columns[0:-1]], df[[df.columns[-1]]], train_size = 0.75)

# %%
plt.scatter(X_train, Y_train)
linreg_2 = LinearRegression()

# %%
X_train_3 = math.sin(X_train_3)
linreg_2.fit(X_train_3, Y_train)
linear_values = np.linspace(0, 100, 100)
Y_predict = linreg.predict([math.sin(x) for i in x])

plt.scatter(X_test, Y_test)
plt.plot(linear_values, Y_predict, color='red')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-533-37fe6cfd641e> in <module>()
# ----> 1 X_train_3 = math.sin(X_train_3)
#       2 linreg_2.fit(X_train_3, Y_train)
#       3 linear_values = np.linspace(0, 100, 100)
#       4 Y_predict = linreg.predict([math.sin(x) for i in x])
#       5
#
# c:\python27\lib\site-packages\pandas\core\series.pyc in wrapper(self)
#      95             return converter(self.iloc[0])
#      96         raise TypeError("cannot convert the series to "
# ---> 97                         "{0}".format(str(converter)))
#      98
#      99     return wrapper
#
# TypeError: cannot convert the series to <type 'float'>
